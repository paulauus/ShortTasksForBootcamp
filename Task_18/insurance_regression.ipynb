# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load dataset
df = pd.read_csv('insurance.csv')
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
# Plot a scatter plot with age on the x-axis and charges on the y-axis
plt.figure()
sns.scatterplot(data=df, x='age', y='charges')
plt.show()
plt.close()

# %%
from sklearn.linear_model import LinearRegression
X = df['age'].values.reshape(-1, 1)
y = df['charges'].values

# Fit a model to the data.
simple_model = LinearRegression()
simple_model.fit(X,y)

# Make predictions on the data.
y_pred = simple_model.predict(X)

# Plot a scatter plot with the best-fit line.
plt.figure()
sns.scatterplot(data=df, x='age', y='charges')
plt.plot(X, y_pred)
plt.show()
plt.close()

# %% [markdown]
# Conclusion: Insurance charges rise consistently with age.
# Extension: There are three groups/clusters of observable data. This requires more research into the variables and the examining/application of multiple linear regression.
